# %% [markdown]
# # Introduction à la programmation Python
#
# Pour ce faire, nous allons commencer avec un petit module de reconnaissance nommé "Turtle".
# Oui! il s'agit de faire se mouvoir une petite tortue qui suit vos instructions (donc si elle se trompe c'est que vous lui avez donné les mauvaises).
# De plus, elle sait écrire! Elle a un stylo que vous pourrez utiliser pour suivre sa trajectoire et ainsi créer des formes géométriques, des frises, des rosaces....
#
# ## I) Les présentations
#
# Ce module ("turtle") fait partie du langage python. On peut donc les retrouver dans tous les IDE python (interface development environment). Nous en classe nous utiliserons *Edupython* , mais libre à vous d'en utiliser d'autre chez vous ...
# ![image-3.png](attachment:image-3.png)
#
#
#
# Je vous présente donc Turtle:
#
# ![image.png](attachment:image.png)
#
# Bon je vous l'accorde, pas de ressemblance, alors essayons celui-là:
# ![image-2.png](attachment:image-2.png)
#
#
# Pour obtenir cette dernière image, j'ai lancé ce programme:

# %%
from turtle import *

shape("turtle")
forward(1)

# %% [markdown]
# ## II) Prise en main de Edupython
#
# ![image.png](attachment:image.png)
#
# Nous utiliserons principalement trois boutons:
#
# |bouton|fonction|
# |---|---|
# |![image-3.png](attachment:image-3.png)|Créer ou ouvrir un programme|
# |![image-4.png](attachment:image-4.png)|Sauvegarder le programme avant exécution|
# |![image-2.png](attachment:image-2.png)|permet d'exécuter le programme|

# %% [markdown]
# **Exercice 1: Ouvrir Edupython et réécrire le programme ci-dessus**
# Qu'obtient-on?

# %% [markdown]
# **Exercice 2:**
# **Utiliser les instructions suivantes en modifiant leur ordre:**
#
# forward(200)
# backward(200)
# left(90)
# right(45)
#
# **Compléter leur fonction:**
#
# |instructions|  fonction ou rôle  |
# |---|---|
# |forward(200)||
# |backward(200)||
# |left(90)||
# |right(45)||
#
# **Exercice 3:**
#
# **Tracer un triangle équilatéral en recopiant ce programme.**
#
# ![image.png](attachment:image.png)
#
#
# **Exercice 4:**
# **Tracer un carré**
# **Tracer un rectangle**
#
# D'autres commandes existent pour modifier l'aspect, je vous laisse les tester:
# ![image-2.png](attachment:image-2.png)
#
# **Exercice 5:**
# **Tenter d'écrire un programme pour obtenir cette image**
# ![image-3.png](attachment:image-3.png)
#
# **Appeler le professeur pour validation**

# %% [markdown]
# # III) Utiliser une boucle
#
# Dans le programme précédent, les instrutions ont été très répétitives. Il est possible de l'éviter en introduisant la boucle POUR (FOR in english).
# Au lieu de répéter n fois l'instruction, on peut simplement l'insérer dans une boucle qui sera exécutée n fois, comme indiqué ci-dessous:
#
# ![image.png](attachment:image.png)
#
# Dans cet exemple, l'instruction est répétée 6 fois.
#
# **Exercice 6:**
# **Refaire l'exercice 5 mais grâce à une boucle.**
#
# **Exercice 7:**
# **Tracer un carré vert avec une boucle**
#
# **Exercice 8:**
# **1) Traduire en Python l'algorithme suivant:**
# ![image-2.png](attachment:image-2.png)
#
# Quelle figure obtient-on?
# **2) Améliorer l'algorithme en utilisant l'instruction input:**
# ![image-3.png](attachment:image-3.png)
#
# **Appeler le professeur pour validation**
#
# **Exercice 9:**
# Ecrire un programme en Python permettant de réaliser la figure suivante :  ![image-4.png](attachment:image-4.png)
#
#
# **Exercice 10:**
# Ecrire un programme en Python permettant de réaliser la figure suivante :  ![image-5.png](attachment:image-5.png)
#
#
#
# **Exercice 11:**
# Ecrire un programme en Python permettant de réaliser la figure suivante :
# ![image-6.png](attachment:image-6.png)
